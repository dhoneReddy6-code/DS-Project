# %% [markdown]
# <a href="https://colab.research.google.com/github/dhoneReddy6-code/DS-Project/blob/main/exp1a_iii.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "RollNo": [1,2,3],
    "Name": ["Reddy", "Dhone", "Ram"],
    "Marks": [95,99, 88]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    RollNo   Name  Marks
# 0       1  Reddy     95
# 1       2  Dhone     99
# 2       3    Ram     88
