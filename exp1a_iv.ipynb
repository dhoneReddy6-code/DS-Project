# %% [markdown]
# <a href="https://colab.research.google.com/github/dhoneReddy6-code/DS-Project/blob/main/exp1a_iv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
student_data = {
    "Roll_No": [1,2,3,4],
    "Name": ["Reddy", "Dhone", "Ram", "Rakesh"],
    "Dept": ["IT", "IT", "CSE", "ECE"],
    "Percentage": [95, 99, 88, 85]
}

df = pd.DataFrame(student_data)
print("Student Data:")
print(df)
df.to_csv("student_output.txt", sep="\t", index=False)
# Out:
# Student Data:
#    Roll_No    Name Dept  Percentage
# 0        1   Reddy   IT          95
# 1        2   Dhone   IT          99
# 2        3     Ram  CSE          88
# 3        4  Rakesh  ECE          85
