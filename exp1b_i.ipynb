# %% [markdown]
# <a href="https://colab.research.google.com/github/dhoneReddy6-code/DS-Project/blob/main/exp1b_i.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
student_data = {
    "Roll No":[1,2,3,4],
    "Name": ["Reddy","Dhone","Ram","Rakesh"],
    "Department":["IT","IT","CSE","DS"],
    "Marks":[95,99,88,85]
}
df = pd.DataFrame(student_data)
df.to_json(
    "students.json",
    orient = "records",
    index = 4
)
print("JSON file created sucessfully")
# Out:
# JSON file created sucessfully
