# %% [markdown]
# <a href="https://colab.research.google.com/github/dhoneReddy6-code/DS-Project/blob/main/Exp4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data=pd.Series(np.random.randn(6),index=[['a','a','b','b','c','c'],[1,2,1,2,1,2]])
print(data)
print(data['b'])
print(data[:,1])
# Out:
# a  1   -1.369613
#    2    0.155775
# b  1    0.912955
#    2   -0.364413
# c  1    0.928065
#    2   -1.558415
# dtype: float64
# 1    0.912955
# 2   -0.364413
# dtype: float64
# a   -1.369613
# b    0.912955
# c    0.928065
# dtype: float64

# %%
df=data.unstack();
print(df);
print(df.stack())
# Out:
#           1         2
# a -1.369613  0.155775
# b  0.912955 -0.364413
# c  0.928065 -1.558415
# a  1   -1.369613
#    2    0.155775
# b  1    0.912955
#    2   -0.364413
# c  1    0.928065
#    2   -1.558415
# dtype: float64

# %%
df1=pd.DataFrame({'a':[1,np.nan,3],'b':[4,5,6,]})
df2=pd.DataFrame({'a':[7,8,9],'b':[np.nan,11,12]})
merged=df1.combine_first(df2)
print(merged)
# Out:
#      a    b
# 0  1.0  4.0
# 1  8.0  5.0
# 2  3.0  6.0
