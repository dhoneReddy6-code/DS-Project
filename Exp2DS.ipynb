# %% [markdown]
# <a href="https://colab.research.google.com/github/dhoneReddy6-code/DS-Project/blob/main/Exp2DS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
url='https://api.github.com/repos/pandas-dev/pandas/issues'
response=requests.get(url)
issues=response.json()
df_issues=pd.DataFrame(issues)
print(df_issues[['id','title','state','created_at']].head())
# Out:
#            id                                              title state  \
# 0  5195329122  BUG: read_csv read a legitimate int64-min / ui...  open
# 1  5195314073  DEPR: Index.fillna casting deprecation missed ...  open
# 2  5195145659  BUG: Fix rename_axis with tuple name for 1D In...  open
# 3  5194802911  BUG: year truncated to 32 bits in the datetime...  open
# 4  5193739952  ENH: add `DatetimeIndexResampler`, `PeriodInde...  open
#
#              created_at
# 0  2026-08-19T17:21:15Z
# 1  2026-08-19T17:19:17Z
# 2  2026-08-19T16:58:33Z
# 3  2026-08-19T16:18:50Z
# 4  2026-08-19T14:27:40Z

# %%
import sqlite3
import pandas as pd
conn=sqlite3.connect("student.db")
cursor=conn.cursor()
cursor.execute('''CREATE TABLE IF NOT EXISTS student(id NUMBER,name TEXT)''')
cursor.execute("INSERT INTO student VALUES(1,'Reddy')")
conn.commit()
cursor.execute("INSERT INTO student VALUES(2,'Dhone')")
conn.commit()
df=pd.read_sql_query("SELECT * FROM student",conn)
print(df)
cursor.execute("UPDATE student SET name='Alice' WHERE id=1")
cursor.execute("DELETE FROM student WHERE id=1")
conn.commit()
conn.close()
# Out:
#    id   name
# 0   1  Reddy
# 1   2  Dhone
