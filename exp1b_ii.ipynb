# %% [markdown]
# <a href="https://colab.research.google.com/github/dhoneReddy6-code/DS-Project/blob/main/exp1b_ii.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

from io import StringIO

json_data = """
[
    {
        "Roll_no": 1,
        "Name": "Reddy",
        "Marks":89
    },


    {
            "Roll_no": 2,
            "Name": "Dhone",
            "Marks":99
     },

    {
            "Roll_no": 3,
            "Name": "Ram",
            "Marks":88
    },

    {
            "Roll_no": 4,
            "Name": "Rakesh",
            "Marks":93
    }
]
"""

df = pd.read_json(StringIO(json_data))
print("Parsed JSON Data")
print(df)
# Out:
# Parsed JSON Data
#    Roll_no    Name  Marks
# 0        1   Reddy     89
# 1        2   Dhone     99
# 2        3     Ram     88
# 3        4  Rakesh     93
